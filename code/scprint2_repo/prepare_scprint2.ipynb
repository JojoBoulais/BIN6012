# %%
# ! lamin init --storage ./testdb --name test --modules bionty
# ! lamin connect anonymous/testdb

# %%
from scdataloader.utils import _adding_scbasecamp_genes, populate_my_ontology, load_genes
import os.path
import urllib.request
import torch

# %load_ext autoreload
# %autoreload 2
# Out:
# → connected lamindb: anonymous/testdb

# %% [markdown]
# # prepare ontologies (just once)

# %%
populate_my_ontology(
    organisms_clade=["vertebrates"],
    sex=["PATO:0000384", "PATO:0000383"],
    organisms=["NCBITaxon:10090", "NCBITaxon:9606"],
    # celltypes=None,
    # ethnicities=None,
    # assays=None,
    # tissues=None,
    # diseases=None,
    # dev_stages=None,
)
_adding_scbasecamp_genes()
# Out:
# → returning celltype with same name: 'unknown'
# ! ambiguous validation in Bionty for 1 record: 'sheep'
# ! ambiguous validation in Bionty for 1 record: 'sheep'
# → returning organism with same name: 'unknown'
# → returning phenotype with same name: 'unknown'
# → returning ethnicity with same name: 'unknown'
# → starting creation of 18326 ExperimentalFactor records in batches of 10000
# → starting creation of 16430 ExperimentalFactor_parents records in batches of 10000
# → returning experimentalfactor with same name: 'unknown'
# → starting creation of 15770 Tissue records in batches of 10000
# → starting creation of 42140 Tissue_parents records in batches of 10000
# → returning tissue with same name: 'unknown'
# → starting creation of 30371 Disease records in batches of 10000
# → starting creation of 39555 Disease_parents records in batches of 10000
# → returning disease with same name: 'normal'
# → returning disease with same name: 'unknown'
# → the database (2.2a3) is ahead of your installed lamindb package (2.1.1)
# → consider updating lamindb: pip install lamindb>=2.2
# ... synchronizing lamin.db.gz: 100.0%
# NCBITaxon:9940
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='1e0pqlXq5sQFgP'), Source(uid='4tsksCMX')
# NCBITaxon:10181
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='2R9u9P71bfitil')
# NCBITaxon:4530
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='6mtjopSB4O7qlq')
# NCBITaxon:9796
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='s7OX44Asd6tWVf')
# NCBITaxon:7227
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='5JGkUUo0X7vEai')
# NCBITaxon:9544
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='2AmW7N1E9JRLcf')
# NCBITaxon:9031
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='4fzSxbbWLepfeA')
# NCBITaxon:7955
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='7bjJiyyCekRwmb')
# NCBITaxon:4577
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='70VIwHUJBXwERK')
# NCBITaxon:9823
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='7N29aZihD42V5f')
# NCBITaxon:4081
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='2Dgc0iBGjH9KM6')
# NCBITaxon:3702
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='7PRZ0StI47pOVE')
# NCBITaxon:9593
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='38ZOM8IOrfjssI')
# NCBITaxon:9913
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='NY4Fwo6nDp6Ypr')
# NCBITaxon:6183
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='5lgRwIC9FvigBy')
# NCBITaxon:9986
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='2cmrlaa86LVWst')
# NCBITaxon:6239
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='5CDgMx83pODPVL')
# NCBITaxon:9598
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='4V2ejovfz6gJL4')
# NCBITaxon:9483
# ! no run & transform got linked, call `ln.track()` & re-run
# → transferred: Organism(uid='3qUn9Zrd0XtCmC')
# → returning organism with same name: 'rice'
# ! updated scientific_name from Oryza sativa to Oryza sativa (main)
# NCBITaxon:9940
# → starting creation of 27992 Gene records in batches of 10000
# NCBITaxon:10181
# → starting creation of 31272 Gene records in batches of 10000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.venv/lib/python3.11/site-packages/django/db/models/query.py:825, in QuerySet.bulk_create(self, objs, batch_size, ignore_conflicts, update_conflicts, update_fields, unique_fields)
#     824 fields = [f for f in fields if not isinstance(f, AutoField)]
# --> 825 returned_columns = self._batched_insert(
#     826     objs_without_pk,
#     827     fields,
#     828     batch_size,
#     829     on_conflict=on_conflict,
#     830     update_fields=update_fields,
#     831     unique_fields=unique_fields,
#     832 )
#     833 connection = connections[self.db]
#
# File ~/.venv/lib/python3.11/site-packages/django/db/models/query.py:1912, in QuerySet._batched_insert(self, objs, fields, batch_size, on_conflict, update_fields, unique_fields)
#    1911     else:
# -> 1912         self._insert(
#    1913             item,
#    1914             fields=fields,
#    1915             using=self.db,
#    1916             on_conflict=on_conflict,
#    1917             update_fields=update_fields,
#    1918             unique_fields=unique_fields,
#    1919         )
#    1920 return inserted_rows
#
# File ~/.venv/lib/python3.11/site-packages/django/db/models/query.py:1873, in QuerySet._insert(self, objs, fields, returning_fields, raw, using, on_conflict, update_fields, unique_fields)
#    1872 query.insert_values(fields, objs, raw=raw)
# -> 1873 return query.get_compiler(using=using).execute_sql(returning_fields)
#
# File ~/.venv/lib/python3.11/site-packages/django/db/models/sql/compiler.py:1882, in SQLInsertCompiler.execute_sql(self, returning_fields)
#    1881 for sql, params in self.as_sql():
# -> 1882     cursor.execute(sql, params)
#    1883 if not self.returning_fields:
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/utils.py:79, in CursorWrapper.execute(self, sql, params)
#      78 def execute(self, sql, params=None):
# ---> 79     return self._execute_with_wrappers(
#      80         sql, params, many=False, executor=self._execute
#      81     )
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/utils.py:92, in CursorWrapper._execute_with_wrappers(self, sql, params, many, executor)
#      91     executor = functools.partial(wrapper, executor)
# ---> 92 return executor(sql, params, many, context)
#
# File ~/.venv/lib/python3.11/site-packages/lamindb_setup/core/django.py:41, in error_no_instance_wrapper(execute, sql, params, many, context)
#      39     raise CurrentInstanceNotConfigured
# ---> 41 return execute(sql, params, many, context)
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/utils.py:105, in CursorWrapper._execute(self, sql, params, *ignored_wrapper_args)
#     104 else:
# --> 105     return self.cursor.execute(sql, params)
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/sqlite3/base.py:360, in SQLiteCursorWrapper.execute(self, query, params)
#     359 query = self.convert_query(query, param_names=param_names)
# --> 360 return super().execute(query, params)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 12
#       1 populate_my_ontology(
#       2     organisms_clade=["vertebrates"],
#       3     sex=["PATO:0000384", "PATO:0000383"],
#    (...)     10     # dev_stages=None,
#      11 )
# ---> 12 _adding_scbasecamp_genes()
#
# File ~/.venv/lib/python3.11/site-packages/scdataloader/utils.py:510, in _adding_scbasecamp_genes(species)
#     500     gene = bt.Gene(
#     501         ensembl_gene_id=row["ensembl_gene_id"],
#     502         stable_id=row["stable_id"],
#    (...)    507         _skip_validation=True,
#     508     )
#     509     genes.append(gene)
# --> 510 ln.save(genes, ignore_conflicts=True)
#
# File ~/.venv/lib/python3.11/site-packages/lamindb/models/save.py:93, in save(records, ignore_conflicts, batch_size)
#      89 if non_artifacts:
#      90     non_artifacts_old, non_artifacts_new = partition(
#      91         lambda r: r._state.adding or r.pk is None, non_artifacts
#      92     )
# ---> 93     bulk_create(
#      94         non_artifacts_new, ignore_conflicts=ignore_conflicts, batch_size=batch_size
#      95     )
#      96     if non_artifacts_old:
#      97         bulk_update(non_artifacts_old, batch_size=batch_size)
#
# File ~/.venv/lib/python3.11/site-packages/lamindb/models/save.py:161, in bulk_create(records, ignore_conflicts, batch_size)
#     157     logger.info(
#     158         f"processing batch {batch_num}/{total_batches} for {model_name}: {len(batch)} records"
#     159     )
#     160 try:
# --> 161     registry.objects.bulk_create(batch, ignore_conflicts=ignore_conflicts)
#     162 # handle unique constraint violations due to non-default branches
#     163 except IntegrityError as e:
#
# File ~/.venv/lib/python3.11/site-packages/django/db/models/manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/django/db/models/query.py:805, in QuerySet.bulk_create(self, objs, batch_size, ignore_conflicts, update_conflicts, update_fields, unique_fields)
#     803 objs = list(objs)
#     804 self._prepare_for_bulk_create(objs)
# --> 805 with transaction.atomic(using=self.db, savepoint=False):
#     806     objs_without_pk, objs_with_pk = partition(lambda o: o._is_pk_set(), objs)
#     807     if objs_with_pk:
#
# File ~/.venv/lib/python3.11/site-packages/django/db/transaction.py:295, in Atomic.__exit__(self, exc_type, exc_value, traceback)
#     292 else:
#     293     # Roll back transaction
#     294     try:
# --> 295         connection.rollback()
#     296     except Error:
#     297         # An error during rollback means that something
#     298         # went wrong with the connection. Drop it.
#     299         connection.close()
#
# File ~/.venv/lib/python3.11/site-packages/django/utils/asyncio.py:26, in async_unsafe.<locals>.decorator.<locals>.inner(*args, **kwargs)
#      24         raise SynchronousOnlyOperation(message)
#      25 # Pass onward.
# ---> 26 return func(*args, **kwargs)
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/base/base.py:337, in BaseDatabaseWrapper.rollback(self)
#     335 self.validate_thread_sharing()
#     336 self.validate_no_atomic_block()
# --> 337 self._rollback()
#     338 # A successful rollback means that the database connection works.
#     339 self.errors_occurred = False
#
# File ~/.venv/lib/python3.11/site-packages/django/db/backends/base/base.py:308, in BaseDatabaseWrapper._rollback(self)
#     306 if self.connection is not None:
#     307     with debug_transaction(self, "ROLLBACK"), self.wrap_database_errors:
# --> 308         return self.connection.rollback()
#
# KeyboardInterrupt:

# %% [markdown]
# # [Optional, only for some models]: solving potential issues
#
# some models have additional elements that are not used anymore and can cause an
# issue when loading them on specific version of pytorch lightning and scPRINT or
# scPRINT2

# %%
m = torch.load(
    model_checkpoint_file, map_location=torch.device("cpu"), weights_only=False
)

# %%
m["hyper_parameters"]["label_decoders"] = {
    k: {u: j if j is not None else "None" for u, j in v.items()}
    for k, v in m["hyper_parameters"]["label_decoders"].items()
}
rn = {
    "expr_encoder.encoder.2.weight": "expr_encoder.encoder.1.weight",
    "expr_encoder.encoder.2.bias": "expr_encoder.encoder.1.bias",
    "expr_encoder.encoder.6.weight": "expr_encoder.encoder.5.weight",
    "expr_encoder.encoder.6.bias": "expr_encoder.encoder.5.bias",
    "expr_decoder.fc.2.weight": "expr_decoder.fc.1.weight",
    "expr_decoder.fc.2.bias": "expr_decoder.fc.1.bias",
    "expr_decoder.fc.6.weight": "expr_decoder.fc.5.weight",
    "expr_decoder.fc.6.bias": "expr_decoder.fc.5.bias",
}
m["state_dict"] = {k if k not in rn else rn[k]: v for k, v in m["state_dict"].items()}

m["hyper_parameters"].pop("checkpointing")
m["hyper_parameters"].pop("residual_in_fp32")
m["hyper_parameters"].pop("fused_dropout_add_ln")
m["hyper_parameters"].pop("checkpointing")
m["hyper_parameters"].pop("fused_mlp")
m["hyper_parameters"].pop("fused_bias_fc")
m["hyper_parameters"].pop("drop_path_rate")
m["hyper_parameters"].pop("class_compression")
m["hyper_parameters"].pop("depth_atinput")
m["hyper_parameters"].pop("cell_transformer_layers")
m["hyper_parameters"].pop("residual_in_fp32")

# %%
torch.save(m, model_checkpoint_file)

# %% [markdown]
# # loading the model
#
# this is what you will need to do every time you load a model

# %%
LOC = "../../models/"  # "../../../"
ckpt_path = os.path.join(LOC, "small-v2.ckpt")
if not os.path.exists(ckpt_path):
    url = "https://huggingface.co/jkobject/scPRINT/resolve/main/small-v2.ckpt"
    urllib.request.urlretrieve(url, ckpt_path)

# %%
model = scPRINT2.load_from_checkpoint(
    ckpt_path,
    precpt_gene_emb=None,
    gene_pos_file=None,
)
if not torch.cuda.is_available():
    model = model.to(torch.float32)

model = model.to("cuda" if torch.cuda.is_available() else "cpu")

# %%
# in some cases the gene ontology has changed too much since I trained the model,
# so I need to remove the genes that are not in the ontology anymore from the model
missing = set(model.genes) - set(load_genes(model.organisms).index)
if len(missing) > 0:
    print(
        "Warning: some genes missmatch exist between model and ontology: solving...",
    )
    model._rm_genes(missing)
